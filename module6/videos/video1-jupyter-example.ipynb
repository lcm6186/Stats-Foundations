# %%
x <- c(1,2,3)
y <- c(1,1.2,2)

# %%
plot(x, y, pch=20, xlim=c(.5,3.5), ylim=c(0.2,2.5))
abline(.3,.52, col="red")

# %%
y1 <- c(.82,1.34,1.86)
points(x, y1)

# %%
lm(y~x)

# %%
lsd.math <- read.csv("~/datasets/lsd-math/lsd-math.csv", header = T, sep=",")

# %%
lsd.math
# Out:
#   tissue.concentration mathscore
# 1                 1.17     78.93
# 2                 2.97     58.20
# 3                 3.26     67.47
# 4                 4.69     37.47
# 5                 5.83     45.65
# 6                 6.00     32.92
# 7                 6.41     29.97

# %%
plot(lsd.math$mathscore,lsd.math$tissue.concentration, xlab="tissue concentration of lsd", ylab="math score")
# Out:
# plot without title

# %%
lm(lsd.math$mathscore~lsd.math$tissue.concentration)
